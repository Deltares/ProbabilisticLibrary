# %% [markdown]
# # Distribution functions
# In this example, we will demonstrate how to define a distribution function using the probabilistic library.
#
# The library supports the following distribution functions: `deterministic`, `normal`, `log_normal`, `uniform`, `triangular`, `trapezoidal`, `exponential`, `gumbel`, `weibull`, `conditional_weibull`, `frechet`, `generalized_extreme_value`, `rayleigh`, `rayleigh_n`, `pareto`, `generalized_pareto`, `student_t`, `gamma`, `beta`, `poisson`, `discrete`, `bernoulli`, `cdf_curve`, `histogram`.
#
# ### Define a stochastic variable
# First, we import the necessary package:

# %%
from probabilistic_library import Stochast, DistributionType, DiscreteValue, HistogramValue, FragilityValue
import numpy as np

# %% [markdown]
# Next, we create a stochastic variable object:

# %%
stochast = Stochast()

# %% [markdown]
# We use the `stochast.get_pdf()` and `stochast.get_cdf()` methods to plot the probability density function and the cumulative distribution function, respectively.

# %%
from utils.plotting import plot_dist

# %% [markdown]
# Below, we demonstrate how to define distribution functions in the library.

# %% [markdown]
# ### Deterministic distribution

# %%
stochast.distribution = DistributionType.deterministic
stochast.mean = 0.8

stochast.print()
# Out:
# Variable:
#   distribution = deterministic
# Definition:
#   location = 0.8
# Derived values:
#   mean = 0.8
#   deviation = 0.0
#   variation = 0.0

# %% [markdown]
# ### Normal distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.normal
stochast.location = 2.0
stochast.scale = 0.5

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = normal
# Definition:
#   location = 2.0
#   scale = 0.5
# Derived values:
#   mean = 2.0
#   deviation = 0.5
#   variation = 0.25

# %% [markdown]
# ### Log-normal distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.log_normal
stochast.location = 0.0
stochast.scale = 1.0
stochast.shift = 0.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = log_normal
# Definition:
#   location = 0.0
#   scale = 1.0
#   shift = 0.0
# Derived values:
#   mean = 1.6487212707001282
#   deviation = 2.1611974158950877
#   variation = 1.3108324944320862

# %% [markdown]
# ### Uniform distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.uniform
stochast.minimum = -1
stochast.maximum = 1

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = uniform
# Definition:
#   minimum = -1.0
#   maximum = 1.0
# Derived values:
#   mean = 0.0
#   deviation = 0.5773502691896257
#   variation = 0.0

# %% [markdown]
# ### Triangular distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.triangular
stochast.minimum = 0.0 # parameter a
stochast.maximum = 3.0 # parameter b
stochast.shift = 2.0 # parameter c

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = triangular
# Definition:
#   minimum = 0.0
#   shift = 2.0
#   maximum = 3.0
# Derived values:
#   mean = 1.6666666666666667
#   deviation = 0.6236095644623235
#   variation = 0.3741657386773941

# %% [markdown]
# ### Trapezoidal distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.trapezoidal
stochast.minimum = 1.0 # parameter a
stochast.maximum = 4.5 # parameter b
stochast.shift = 2.0 # parameter c
stochast.shift_b = 3.0 # parameter d

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = trapezoidal
# Definition:
#   minimum = 1.0
#   shift = 2.0
#   shift_b = 3.0
#   maximum = 4.5
# Derived values:
#   mean = 2.6481481481481484
#   deviation = 0.7461607265891025
#   variation = 0.2817669876630177

# %% [markdown]
# ### Exponential distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.exponential
stochast.scale = 2.0
stochast.shift = 0.5

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = exponential
# Definition:
#   scale = 2.0
#   shift = 0.5
# Derived values:
#   mean = 2.5
#   deviation = 2.0
#   variation = 0.8

# %% [markdown]
# ### Gumbel distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.gumbel
stochast.scale = 2.0
stochast.shift = 3.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = gumbel
# Definition:
#   scale = 2.0
#   shift = 3.0
# Derived values:
#   mean = 4.1544313298030655
#   deviation = 2.565099660323728
#   variation = 0.6174370104332241

# %% [markdown]
# ### Weibull distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.weibull
stochast.scale = 1.0
stochast.shift = 1.0
stochast.shape = 2.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = weibull
# Definition:
#   scale = 1.0
#   shift = 1.0
#   shape = 2.0
# Derived values:
#   mean = 1.886226925452754
#   deviation = 0.4632513751761116
#   variation = 0.24559684146429872

# %% [markdown]
# ### Conditional Weibull distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.conditional_weibull
stochast.scale = 1.0
stochast.shift = 5.0
stochast.shape = 2.0
stochast.shape_b = 1.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = conditional_weibull
# Definition:
#   scale = 1.0
#   shift = 5.0
#   shape = 2.0
#   shape_b = 1.0
# Derived values:
#   mean = 5.055816301778746
#   deviation = 0.1250782676640421
#   variation = 0.024739480273449976

# %% [markdown]
# ### Frechet distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.frechet
stochast.scale = 0.5
stochast.shift = 1.0
stochast.shape = 2.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = frechet
# Definition:
#   scale = 0.5
#   shift = 1.0
#   shape = 2.0
# Derived values:
#   mean = 1.8862269254527961
#   deviation = inf
#   variation = inf

# %% [markdown]
# ### Generalized extreme value distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.generalized_extreme_value
stochast.scale = 1.0
stochast.shift = 5.0
stochast.shape = -0.5

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = generalized_extreme_value
# Definition:
#   scale = 1.0
#   shift = 5.0
#   shape = -0.5
# Derived values:
#   mean = 5.227546149094492
#   deviation = 0.9265027503522232
#   variation = 0.17723473383639296

# %% [markdown]
# ### Rayleigh distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.rayleigh
stochast.scale = 0.5
stochast.shift = 1.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = rayleigh
# Definition:
#   scale = 0.5
#   shift = 1.0
# Derived values:
#   mean = 1.62665706865775
#   deviation = 0.3275681887810168
#   variation = 0.20137507474228264

# %% [markdown]
# ### Rayleigh N distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.rayleigh_n
stochast.scale = 1.0
stochast.shift = 0.0
stochast.shape = 50.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = rayleigh_n
# Definition:
#   scale = 1.0
#   shift = 0.0
#   shape = 50.0
# Derived values:
#   mean = 2.971809636524949
#   deviation = 0.40780046990496344
#   variation = 0.1372229448659505

# %% [markdown]
# ### Pareto distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.pareto
stochast.scale = 1.0
stochast.shape = 3.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = pareto
# Definition:
#   scale = 1.0
#   shape = 3.0
# Derived values:
#   mean = 1.5
#   deviation = 0.8660254037844386
#   variation = 0.5773502691896257

# %% [markdown]
# ### Generalized Pareto distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.generalized_pareto
stochast.shape = 0.1
stochast.scale = 1.0
stochast.shift = 1.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = generalized_pareto
# Definition:
#   scale = 1.0
#   shift = 1.0
#   shape = 0.1
# Derived values:
#   mean = 1.9089509164697132
#   deviation = 0.8294480259389108
#   variation = 0.43450463748582746

# %% [markdown]
# ### Student's t-distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.student_t
stochast.location = 0.0
stochast.scale = 1.0
stochast.observations = 5

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = student_t
# Definition:
#   location = 0.0
#   scale = 1.0
#   observations = 5
# Derived values:
#   mean = 0.0
#   deviation = 1.4142135623730951
#   variation = 0.0

# %% [markdown]
# ### Gamma distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.gamma
stochast.scale = 2.0
stochast.shape = 4.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = gamma
# Definition:
#   scale = 2.0
#   shape = 4.0
# Derived values:
#   mean = 8.0
#   deviation = 4.0
#   variation = 0.5

# %% [markdown]
# ### Beta distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.beta
stochast.shape = 2.0
stochast.shape_b = 2.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = beta
# Definition:
#   shape = 2.0
#   shape_b = 2.0
# Derived values:
#   mean = 0.5
#   deviation = 0.22360679774997896
#   variation = 0.4472135954999579

# %% [markdown]
# ### Poisson distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.poisson
stochast.location = 4.0

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = poisson
# Definition:
#   scale = 0.0
#   shift = 0.0
# Derived values:
#   mean = 4.0
#   deviation = 2.0
#   variation = 0.5

# %% [markdown]
# ### Discrete distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.discrete

x = [1, 2, 3]
amount = [0.1, 0.4, 0.5]

for i in range(0, len(x)):
    
    dv = DiscreteValue()
    dv.x = x[i]
    dv.amount = amount[i]

    stochast.discrete_values.append(dv)

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = discrete
# Definition:
#   amount[1.0] = 0.1
#   amount[2.0] = 0.4
#   amount[3.0] = 0.5
# Derived values:
#   mean = 2.4
#   deviation = 0.6633249580710799
#   variation = 0.2763853991962833

# %% [markdown]
# ### Bernoulli distribution

# %%
stochast = Stochast()
stochast.distribution = DistributionType.bernoulli
stochast.mean = 0.3

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = bernoulli
# Definition:
#   location = 0.3
# Derived values:
#   mean = 0.3
#   deviation = 0.458257569495584
#   variation = 1.5275252316519468

# %% [markdown]
# ### CDF curve distribution

# %%
stochast = Stochast()
stochast.distribution =  DistributionType.cdf_curve

x = [1, 2, 3]
probability_of_failure = [0.01, 0.001, 0.0001] 

# these are the exceedance probabilities, which will shift the probability mass to an area < 1.0

for i in range(0, len(x)):

    fc = FragilityValue()
    fc.x = x[i]
    fc.probability_of_failure = probability_of_failure[i]
    
    stochast.fragility_values.append(fc)

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = cdf_curve
# Definition:
#   beta[1.0] = 2.3263478740408408
#   beta[2.0] = 3.090232306167813
#   beta[3.0] = 3.71901648545568
# Derived values:
#   mean = -2.045362283930628
#   deviation = 1.309088277127278
#   variation = 0.6400275821120393

# %% [markdown]
# ### Histogram distribution

# %%
stochast = Stochast()
stochast.distribution =  DistributionType.histogram

lower_bound = [1, 2, 3]
upper_bound = [2, 3, 4]
amount = [100, 200, 300]

for i in range(0, len(lower_bound)):

    hv = HistogramValue()
    hv.lower_bound = lower_bound[i]
    hv.upper_bound = upper_bound[i]
    hv.amount = amount[i]
    stochast.histogram_values.append(hv)

stochast.print()
stochast.plot()
# Out:
# Variable:
#   distribution = histogram
# Definition:
#   amount[1.0, 2.0] = 100.0
#   amount[2.0, 3.0] = 200.0
#   amount[3.0, 4.0] = 300.0
# Derived values:
#   mean = 2.833333333333333
#   deviation = 0.7459778999860978
#   variation = 0.26328631764215216
